# %%
import cv2
import numpy as np

def capture_template():
    # To capture video from webcam. 
    cap = cv2.VideoCapture(0)

    # select region
    while True:
        # Read the frame and Convert to grayscale
        _, img = cap.read()
        img = cv2.flip(img, 1)

        gray = #????????? convert color image to gray 
        
        # draw rectangle area
        top_left = (200,300)
        bottom_right = (400,400)
        
        #????????? use img to draw bounding box using top_left and bottom_right

        # Display
        cv2.imshow('img', img)

        # press the 'c' key
        if cv2.waitKey(33) == ord('c'):  
            break

    # create a template
    template = #????????? use the gray, top_left and bottom_right to crop the area of template (bounding box) 
    
    cv2.imshow('template', template)
    cv2.waitKey(0) # press any keys
    
    return cap, template

def track_object(cap, template):
    # tracking
    while True:
        # Read the frame and Convert to grayscale
        _, img = cap.read()
        img = cv2.flip(img, 1)
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

        corr_map = cv2.matchTemplate(gray, template, cv2.TM_CCOEFF_NORMED)
        min_val, max_val, min_loc, max_loc = cv2.minMaxLoc(corr_map) 

        # take minimum
        top_left = max_loc
        h, w = #????????? get height and width of the template
        bottom_right = #????????? find bottom_right by using top_left, h, w

        # draw 
        #????????? use img to draw bounding box using top_left and bottom_right


        # Display
        cv2.imshow('img', img)

        # press the 'e' key
        if cv2.waitKey(33) == ord('e'):  
            break
    
    return cap

def release(cap):
    # Release the VideoCapture object
    cap.release()
    cv2.destroyAllWindows()

# %%
cap, template = capture_template()
cap = track_object(cap, template)
release(cap)
